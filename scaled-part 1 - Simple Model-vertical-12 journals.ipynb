# %% [markdown]
# # Loading Data

# %%
data <- read.csv("D:/Research/keyword/Keyword/All/12 journals.csv")
nrow(data)
# str(data)
# head(data$abstract_ratio)
# sum(data[which(data$source.title=="computers and education"),"no_references"])
# Out:
# [1] 5875

# %% [markdown]
# # Transforming Variables

# %%
summary(data$cited.by_scaled)
na_index <- which(is.na(data$cited.by))
na_index
##data[na_index, "cited.by"] <- 0
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# -0.8171 -0.5039 -0.2998  0.0000  0.1267 20.8200
# integer(0)

# %% [markdown]
# # Data Cleaning

# %%
nrow(data)
summary(data$cited.by_scaled)

data <- data[data$cited.by_scaled <4,]
nrow(data)
summary(data$cited.by_scaled)
# Out:
# [1] 5875
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# -0.8171 -0.5039 -0.2998  0.0000  0.1267 20.8200
# [1] 5808
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# -0.8171 -0.5194 -0.3008 -0.0697  0.1109  3.9610

# %%
# cited.by.table <- table(data$cited.by)
# # cited.by.table
# # round(prop.table(cited.by.table),2) # row percentages 
# rbind(cited.by.table,round(prop.table(cited.by.table),2))

# ##------------------------------------
# cited.by.table <- table(log(data$cited.by_zero))
# # cited.by.table
# # round(prop.table(cited.by.table),2) # row percentages 
# rbind(cited.by.table,round(prop.table(cited.by.table),2))

# %% [markdown]
# # Creating New Target Variables

# %%
# data$cited.by_zero <- 0


# for (row in 1:nrow(data))
# #     row=1
#     {if (data[row,"cited.by"] == 0  & !(is.na(data[row,"cited.by"])))
#     data[row,"cited.by_zero"] <- data[row,"cited.by"] + 0.5
#     else data[row,"cited.by_zero"] <- data[row,"cited.by"] }
     
# #hist(log(data$cited.by_zero))
    
     
# hist   (log(data$cited.by_zero))
# #barplot(log(data$cited.by_zero))

# %% [markdown]
# # Part 1: Linear Regression for all data points-scaled

# %%
data$cited.by_scaled_trans <- 0

require(MASS,quietly=TRUE) 
pred_numeric <- c("abstract_length" ,"page.count","title_length", "abstract_ratio" ,"no_references","no_authors"
                  ,"numkeys", "cited.by_scaled", "article_age","weight_ratio")
pred_cat     <- c("quarter")
pred_data     <- data[,c(pred_numeric,pred_cat)]
##-----------------------------------------------------------
pred_numeric2 <- c("abstract_length" ,"page.count","title_length", "abstract_ratio" ,"no_references","no_authors"
                  ,"numkeys", "cited.by_scaled_trans", "article_age","weight_ratio")
pred_cat2     <- c("quarter")
pred_data2     <- data[,c(pred_numeric2,pred_cat2)]

# tail(pred_data2)
linear_reg   <- lm(cited.by_scaled ~ ., data=pred_data)
# summary(linear_reg)

data$cited.by_scaled_trans <- yjPower(data$cited.by_scaled, -1, jacobian.adjusted = FALSE)
pred_data2     <- data[,c(pred_numeric2,pred_cat2)]


linear_reg_trans <- lm(cited.by_scaled_trans ~ ., data=pred_data2)
summary(linear_reg_trans)
# Out:
# Call:
# lm(formula = cited.by_scaled_trans ~ ., data = pred_data2)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.63469 -0.34713 -0.02947  0.34557  1.37895
#
# Coefficients:
#                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)     -1.0297132  0.0449045 -22.931  < 2e-16 ***
# abstract_length  0.0004150  0.0001283   3.234 0.001228 **
# page.count      -0.0174523  0.0018588  -9.389  < 2e-16 ***
# title_length    -0.0031089  0.0015966  -1.947 0.051557 .
# abstract_ratio   1.0166019  0.2629509   3.866 0.000112 ***
# no_references    0.0037819  0.0003048  12.409  < 2e-16 ***
# no_authors       0.0181954  0.0047269   3.849 0.000120 ***
# numkeys         -0.0006727  0.0051937  -0.130 0.896952
# article_age      0.0969704  0.0022395  43.300  < 2e-16 ***
# weight_ratio     0.5079453  0.2117558   2.399 0.016483 *
# quarterq2        0.1791566  0.0184825   9.693  < 2e-16 ***
# quarterq3        0.0279917  0.0239677   1.168 0.242899
# quarterq4        0.1151111  0.0443433   2.596 0.009458 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.4956 on 5795 degrees of freedom
# Multiple R-squared:  0.2666,	Adjusted R-squared:  0.2651
# F-statistic: 175.6 on 12 and 5795 DF,  p-value: < 2.2e-16

# %% [markdown]
# # Model Selection

# %%
# linear_reg_step <- step(linear_reg)
# linear_reg_step

# %%
# linear_reg_final <- lm(log(cited.by_zero) ~ page.count + abstract_ratio + 
#     no_references + article_age + source.title, data = pred_data)
# summary(linear_reg_final)

# %%
require(car,quietly=TRUE)
qqPlot <- qqPlot(linear_reg_trans, main="QQ Plot") #qq plot for studentized resid 
# qqPlot(linear_reg0, main="QQ Plot") #qq plot for studentized resid 
# str(qqPlot)
# Out:
# Plot with title "QQ Plot"

# %% [markdown]
# # Outlier Detection

# %%
# outlierResult <-outlierTest(linear_reg_trans)
# # str(outlierResult)
# outlierResult$rstudent
# data[c(531,2502,967,365),]

# %%
# influenceIndexPlot <- influenceIndexPlot(linear_reg, id.n=10)
# str(influenceIndexPlot)
# outlierTest(linear_reg)
# data[c(921,922,923),]

# %%
# # Influence Plot 
# influencePlot(linear_reg,	id.method="identify", main="Influence Plot", 
#               sub="Circle size is proportial to Cook's Distance",id.n=10 )

# %% [markdown]
# # Box-Cox Transformation

# %%
require(MASS, quietly=TRUE)
require(car, quietly=TRUE)

#bcPower(1:5,2)
boxCox <- boxCox(linear_reg, lambda = seq(-2, 2, by=0.1),family="yjPower")
# family: Defaults to "bcPower" for the Box-Cox power family of transformations. If set to "yjPower" the Yeo-Johnson family, 
#     which permits negative responses, is used.

#summary(powerTransform(linear_reg))

#bcPower(linear_reg)
# data$cited.by_zero[1:5]
# basicPower(data$cited.by_zero,lambda=0.05)[1:5]
# Out:
# plot without title

# %% [markdown]
# # Multi-Collinearity

# %%
require(car,quietly=TRUE)
# Evaluate Collinearity

vif(linear_reg) # variance inflation factors 
# ??vif
sqrt(vif(linear_reg)) > 2 # problem?
# Out:
#                     GVIF Df GVIF^(1/(2*Df))
# abstract_length 1.121395  1        1.058959
# page.count      1.230075  1        1.109087
# title_length    1.059200  1        1.029175
# abstract_ratio  1.557527  1        1.248009
# no_references   1.352830  1        1.163112
# no_authors      1.099088  1        1.048374
# numkeys         1.200958  1        1.095882
# article_age     1.470111  1        1.212481
# weight_ratio    1.368877  1        1.169990
# source.title    1.547148  3        1.075446
#                  GVIF    Df GVIF^(1/(2*Df))
# abstract_length FALSE FALSE           FALSE
# page.count      FALSE FALSE           FALSE
# title_length    FALSE FALSE           FALSE
# abstract_ratio  FALSE FALSE           FALSE
# no_references   FALSE FALSE           FALSE
# no_authors      FALSE FALSE           FALSE
# numkeys         FALSE FALSE           FALSE
# article_age     FALSE FALSE           FALSE
# weight_ratio    FALSE FALSE           FALSE
# source.title    FALSE FALSE           FALSE

# %%
confint(linear_reg)
confint(linear_reg2)
# Out:
#                                            2.5 %       97.5 %
# (Intercept)                         -29.62180646 -10.56558169
# abstract_length                      -0.04850754   0.00531413
# page.count                            0.17111616   0.95590560
# title_length                         -0.49949594   0.19057742
# abstract_ratio                       25.23705315 144.23139006
# no_references                         0.05223696   0.21216736
# no_authors                           -1.16743218   0.73312095
# numkeys                              -0.60867130   1.77403031
# article_age                           2.70568141   3.77304059
# source.titlecomputers and education  13.63812024  24.34024598
#                                            2.5 %        97.5 %
# (Intercept)                         -0.699594432  1.8189091038
# abstract_length                     -0.008204656 -0.0008581487
# page.count                          -0.011296098  0.0870355989
# title_length                        -0.081702954  0.0130371166
# abstract_ratio                       0.622934827 17.0929026607
# no_references                        0.012086150  0.0321882777
# no_authors                          -0.140077705  0.1206526700
# numkeys                             -0.073870098  0.2560488839
# source.titlecomputers and education  2.681360673  4.0785562615

# %%
# hist(log(data$cited.by+0.5))

# %%
save.image()
