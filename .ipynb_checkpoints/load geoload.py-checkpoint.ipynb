# %%
# %load geoload.py
import urllib
import sqlite3
import json
import time
import ssl

# If you are in China use this URL:
# serviceurl = "http://maps.google.cn/maps/api/geocode/json?"
serviceurl = "http://maps.googleapis.com/maps/api/geocode/json?"

# Deal with SSL certificate anomalies Python > 2.7
# scontext = ssl.SSLContext(ssl.PROTOCOL_TLSv1)
scontext = None

conn = sqlite3.connect('geodata.sqlite')
cur = conn.cursor()

cur.execute('''
CREATE TABLE IF NOT EXISTS Locations (address TEXT, geodata TEXT)''')

fh = open("where.data")
count = 0
for line in fh:
    if count > 200 : break
    address = line.strip()
    print ''
    cur.execute("SELECT geodata FROM Locations WHERE address= ?", (buffer(address), ))

    try:
        data = cur.fetchone()[0]
        print "Found in database ",address
        continue
    except:
        pass

    print 'Resolving', address
    url = serviceurl + urllib.urlencode({"sensor":"false", "address": address})
    print 'Retrieving', url
    uh = urllib.urlopen(url, context=scontext)
    data = uh.read()
    print 'Retrieved',len(data),'characters',data[:20].replace('\n',' ')
    count = count + 1
    try: 
        js = json.loads(str(data))
        # print js  # We print in case unicode causes an error
    except: 
        continue

    if 'status' not in js or (js['status'] != 'OK' and js['status'] != 'ZERO_RESULTS') : 
        print '==== Failure To Retrieve ===='
        print data
        break

    cur.execute('''INSERT INTO Locations (address, geodata) 
            VALUES ( ?, ? )''', ( buffer(address),buffer(data) ) )
    conn.commit() 
    time.sleep(1)

print "Run geodump.py to read the data from the database so you can visualize it on a map."
# Out:
# Resolving ﻿Northeastern University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=%EF%BB%BFNortheastern+University
# Retrieved 8354 characters {    "results" : [
#
# Resolving University of Hong Kong, Illinois Institute of Technology, Bradley University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Hong+Kong%2C+Illinois+Institute+of+Technology%2C+Bradley+University
# Retrieved 12982 characters {    "results" : [
#
# Resolving Technion
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Technion
# Retrieved 1816 characters {    "results" : [
#
# Resolving Viswakarma Institute, Pune, India
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Viswakarma+Institute%2C+Pune%2C+India
# Retrieved 5489 characters {    "results" : [
#
# Resolving UMD
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=UMD
# Retrieved 2455 characters {    "results" : [
#
# Resolving Tufts University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Tufts+University
# Retrieved 4726 characters {    "results" : [
#
# Resolving Monash University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Monash+University
# Retrieved 3966 characters {    "results" : [
#
# Resolving Kokshetau Institute of Economics and Management
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Kokshetau+Institute+of+Economics+and+Management
# Retrieved 1942 characters {    "results" : [
#
# Resolving RSU named S.A. Esenin
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=RSU+named+S.A.+Esenin
# Retrieved 52 characters {    "results" : [],
#
# Resolving Tavrida National V.I. Vernadsky University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Tavrida+National+V.I.+Vernadsky+University
# Retrieved 52 characters {    "results" : [],
#
# Resolving UOC
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=UOC
# Retrieved 1580 characters {    "results" : [
#
# Resolving Irkutsk State University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Irkutsk+State+University
# Retrieved 1787 characters {    "results" : [
#
# Resolving Institute of Technology Telkom
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Institute+of+Technology+Telkom
# Retrieved 52 characters {    "results" : [],
#
# Resolving Shanghai Jiao Tong University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Shanghai+Jiao+Tong+University
# Retrieved 14361 characters {    "results" : [
#
# Resolving University of Ilorin, Kwara State. Nigeria
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Ilorin%2C+Kwara+State.+Nigeria
# Retrieved 6307 characters {    "results" : [
#
# Resolving Monash University Churchill Australia
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Monash+University+Churchill+Australia
# Retrieved 52 characters {    "results" : [],
#
# Resolving UNISA
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=UNISA
# Retrieved 7069 characters {    "results" : [
#
# Resolving Fachhochschule FH Salzburg
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Fachhochschule+FH+Salzburg
# Retrieved 1737 characters {    "results" : [
#
# Resolving Tampere University of Technology (Tampere, Finland)
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Tampere+University+of+Technology+%28Tampere%2C+Finland%29
# Retrieved 1774 characters {    "results" : [
#
# Resolving Saint Petersburg State University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Saint+Petersburg+State+University
# Retrieved 3549 characters {    "results" : [
#
# Resolving University of São Paulo
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+S%C3%A3o+Paulo
# Retrieved 16959 characters {    "results" : [
#
# Resolving Smolensk State University (Russia)
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Smolensk+State+University+%28Russia%29
# Retrieved 1783 characters {    "results" : [
#
# Resolving Institute of Business Administration, Karachi
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Institute+of+Business+Administration%2C+Karachi
# Retrieved 1758 characters {    "results" : [
#
# Resolving universidad complutense de madrid
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=universidad+complutense+de+madrid
# Retrieved 1929 characters {    "results" : [
#
# Resolving Masdar Institute
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Masdar+Institute
# Retrieved 9714 characters {    "results" : [
#
# Resolving University of London
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+London
# Retrieved 6079 characters {    "results" : [
#
# Resolving University of Oxford
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Oxford
# Retrieved 2114 characters {    "results" : [
#
# Resolving Tallinn University of Technology
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Tallinn+University+of+Technology
# Retrieved 2142 characters {    "results" : [
#
# Resolving University of Tartu
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Tartu
# Retrieved 1864 characters {    "results" : [
#
# Resolving University of Padua
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Padua
# Retrieved 19738 characters {    "results" : [
#
# Resolving University of Pune, India
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Pune%2C+India
# Retrieved 6586 characters {    "results" : [
#
# Resolving National Kyiv Shevchenko University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=National+Kyiv+Shevchenko+University
# Retrieved 52 characters {    "results" : [],
#
# Resolving UC Berkeley
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=UC+Berkeley
# Retrieved 12667 characters {    "results" : [
#
# Resolving University of Wisconsin - Madison
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Wisconsin+-+Madison
# Retrieved 2441 characters {    "results" : [
#
# Resolving Lodz University of Technology
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Lodz+University+of+Technology
# Retrieved 2429 characters {    "results" : [
#
# Resolving NRU IFMO
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=NRU+IFMO
# Retrieved 52 characters {    "results" : [],
#
# Resolving Dniepropetrovsk National University (Ukraine), Applied Math Faculty
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Dniepropetrovsk+National+University+%28Ukraine%29%2C+Applied+Math+Faculty
# Retrieved 52 characters {    "results" : [],
#
# Resolving Dokuz Eylul University, Izmir, Turkey
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Dokuz+Eylul+University%2C+Izmir%2C+Turkey
# Retrieved 6306 characters {    "results" : [
#
# Resolving Beijing normal university
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Beijing+normal+university
# Retrieved 15208 characters {    "results" : [
#
# Resolving University of Piraeus, Athens
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Piraeus%2C+Athens
# Retrieved 9169 characters {    "results" : [
#
# Resolving Universidad de Buenos Aires (UBA). Argentina.
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Universidad+de+Buenos+Aires+%28UBA%29.+Argentina.
# Retrieved 52 characters {    "results" : [],
#
# Resolving SASTRA University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=SASTRA+University
# Retrieved 2156 characters {    "results" : [
#
# Resolving Nagpur University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Nagpur+University
# Retrieved 6761 characters {    "results" : [
#
# Resolving Duke University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Duke+University
# Retrieved 6448 characters {    "results" : [
#
# Resolving San Francisco State University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=San+Francisco+State+University
# Retrieved 2281 characters {    "results" : [
#
# Resolving FATEC-SP - Faculdade de Tecnologia do Estado de São Paulo
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=FATEC-SP+-+Faculdade+de+Tecnologia+do+Estado+de+S%C3%A3o+Paulo
# Retrieved 1825 characters {    "results" : [
#
# Resolving University of Texas at Austin
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Texas+at+Austin
# Retrieved 1994 characters {    "results" : [
#
# Resolving University of applied sciense of Mikkeli (Finland)
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+applied+sciense+of+Mikkeli+%28Finland%29
# Retrieved 1413 characters {    "results" : [
#
# Resolving Troy University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Troy+University
# Retrieved 4627 characters {    "results" : [
#
# Resolving Universidade do Minho
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Universidade+do+Minho
# Retrieved 1787 characters {    "results" : [
#
# Resolving National University of Sciences and Technology (NUST)-Pakistan
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=National+University+of+Sciences+and+Technology+%28NUST%29-Pakistan
# Retrieved 13569 characters {    "results" : [
#
# Resolving Pontificia universidad catolica de chile
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Pontificia+universidad+catolica+de+chile
# Retrieved 4360 characters {    "results" : [
#
# Resolving Illinois State University Joliet Junior College
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Illinois+State+University+Joliet+Junior+College
# Retrieved 1448 characters {    "results" : [
#
# Resolving American University in Cairo (AUC)
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=American+University+in+Cairo+%28AUC%29
# Retrieved 3510 characters {    "results" : [
#
# Resolving Obninsk Technical University of Nuclear Power Engineering, Russia
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Obninsk+Technical+University+of+Nuclear+Power+Engineering%2C+Russia
# Retrieved 1768 characters {    "results" : [
#
# Resolving Vyatka State Humanitarian University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Vyatka+State+Humanitarian+University
# Retrieved 52 characters {    "results" : [],
#
# Resolving Weizmann Institute of Science (Israel)
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Weizmann+Institute+of+Science+%28Israel%29
# Retrieved 52 characters {    "results" : [],
#
# Resolving University of Washington
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Washington
# Retrieved 11869 characters {    "results" : [
#
# Resolving Kharkiv State Academy of Municipal Economy, Ukraine
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Kharkiv+State+Academy+of+Municipal+Economy%2C+Ukraine
# Retrieved 1798 characters {    "results" : [
#
# Resolving Faculty of Electrical Engineering in Sarajevo, University of Sarajevo
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Faculty+of+Electrical+Engineering+in+Sarajevo%2C+University+of+Sarajevo
# Retrieved 1849 characters {    "results" : [
#
# Resolving Universidad de Los Andes Colombia
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Universidad+de+Los+Andes+Colombia
# Retrieved 6778 characters {    "results" : [
#
# Resolving University of Colorado at Boulder
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Colorado+at+Boulder
# Retrieved 1896 characters {    "results" : [
#
# Resolving Magnitogorsk State Technical University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Magnitogorsk+State+Technical+University
# Retrieved 1817 characters {    "results" : [
#
# Resolving USC
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=USC
# Retrieved 1596 characters {    "results" : [
#
# Resolving Simon Fraser University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Simon+Fraser+University
# Retrieved 2365 characters {    "results" : [
#
# Resolving Columbia University (New York)
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Columbia+University+%28New+York%29
# Retrieved 2310 characters {    "results" : [
#
# Resolving University of Southern California
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Southern+California
# Retrieved 5985 characters {    "results" : [
#
# Resolving University of Warsaw
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Warsaw
# Retrieved 4165 characters {    "results" : [
#
# Resolving Warsaw University of Technology
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Warsaw+University+of+Technology
# Retrieved 5978 characters {    "results" : [
#
# Resolving (Some place in New Zealand you haven't heard of.)
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=%28Some+place+in+New+Zealand+you+haven%27t+heard+of.%29
# Retrieved 1234 characters {    "results" : [
#
# Resolving Massey university part-time Distance learning
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Massey+university+part-time+Distance+learning
# Retrieved 2103 characters {    "results" : [
#
# Resolving University of Oklahoma
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Oklahoma
# Retrieved 6108 characters {    "results" : [
#
# Resolving University of Pavia, Italy
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Pavia%2C+Italy
# Retrieved 2105 characters {    "results" : [
#
# Resolving University of Missouri - Columbia
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Missouri+-+Columbia
# Retrieved 14965 characters {    "results" : [
#
# Resolving Czech Technical University in Prague
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Czech+Technical+University+in+Prague
# Retrieved 1775 characters {    "results" : [
#
# Resolving Illinois Institute of Technology
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Illinois+Institute+of+Technology
# Retrieved 5466 characters {    "results" : [
#
# Resolving Penn State University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Penn+State+University
# Retrieved 1762 characters {    "results" : [
#
# Resolving University of Utah
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Utah
# Retrieved 8465 characters {    "results" : [
#
# Resolving Faculty of Science, University of Zagreb - Department of Mathematics
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Faculty+of+Science%2C+University+of+Zagreb+-+Department+of+Mathematics
# Retrieved 52 characters {    "results" : [],
#
# Resolving Universitat Politecnica de Valencia
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Universitat+Politecnica+de+Valencia
# Retrieved 2020 characters {    "results" : [
#
# Resolving University of Vienna
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Vienna
# Retrieved 8139 characters {    "results" : [
#
# Resolving University of Puerto Rico - Mayaguez Campus
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Puerto+Rico+-+Mayaguez+Campus
# Retrieved 52 characters {    "results" : [],
#
# Resolving University "Hyperion" of Bucharest
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+%22Hyperion%22+of+Bucharest
# Retrieved 1752 characters {    "results" : [
#
# Resolving University of New Haven
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+New+Haven
# Retrieved 12433 characters {    "results" : [
#
# Resolving University of Washington -Bothell
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Washington+-Bothell
# Retrieved 2004 characters {    "results" : [
#
# Resolving Drexel University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Drexel+University
# Retrieved 10720 characters {    "results" : [
#
# Found in database  University of Texas at Austin
#
# Resolving University of Helsinki
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Helsinki
# Retrieved 1762 characters {    "results" : [
#
# Resolving University of Michigan
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Michigan
# Retrieved 17123 characters {    "results" : [
#
# Resolving Carnegie Mellon University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Carnegie+Mellon+University
# Retrieved 2266 characters {    "results" : [
#
# Resolving Kazan Federal University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Kazan+Federal+University
# Retrieved 1773 characters {    "results" : [
#
# Resolving Pondicherry University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Pondicherry+University
# Retrieved 2125 characters {    "results" : [
#
# Resolving Far-Eastern State University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Far-Eastern+State+University
# Retrieved 52 characters {    "results" : [],
#
# Resolving Nanyang Technological University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Nanyang+Technological+University
# Retrieved 6727 characters {    "results" : [
#
# Resolving Slovak University of Technology
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Slovak+University+of+Technology
# Retrieved 52 characters {    "results" : [],
#
# Resolving NYU
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=NYU
# Retrieved 9724 characters {    "results" : [
#
# Resolving UFABC - Universidade Federal do ABC, Sanso André - SP - Brazil
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=UFABC+-+Universidade+Federal+do+ABC%2C+Sanso+Andr%C3%A9+-+SP+-+Brazil
# Retrieved 1443 characters {    "results" : [
#
# Resolving University of Debrecen
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Debrecen
# Retrieved 1947 characters {    "results" : [
#
# Resolving California State University, San Bernardino
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=California+State+University%2C+San+Bernardino
# Retrieved 1780 characters {    "results" : [
#
# Resolving National University "Kyiv-Mohyla Academy" (Kyiv, Ukraine)
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=National+University+%22Kyiv-Mohyla+Academy%22+%28Kyiv%2C+Ukraine%29
# Retrieved 1887 characters {    "results" : [
#
# Resolving Laurentian University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Laurentian+University
# Retrieved 2544 characters {    "results" : [
#
# Resolving Humanities Institute of TV and Radio, Moscow, Russia
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Humanities+Institute+of+TV+and+Radio%2C+Moscow%2C+Russia
# Retrieved 5641 characters {    "results" : [
#
# Resolving University of Cambridge, UK
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Cambridge%2C+UK
# Retrieved 2122 characters {    "results" : [
#
# Resolving Payame Noor University, Tehran, Iran
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Payame+Noor+University%2C+Tehran%2C+Iran
# Retrieved 1898 characters {    "results" : [
#
# Resolving Middle East Technical University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Middle+East+Technical+University
# Retrieved 5821 characters {    "results" : [
#
# Resolving EPFL
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=EPFL
# Retrieved 1753 characters {    "results" : [
#
# Resolving Faculty of Technical Sciences, Novi Sad, Serbia
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Faculty+of+Technical+Sciences%2C+Novi+Sad%2C+Serbia
# Retrieved 1951 characters {    "results" : [
#
# Resolving University of Gothenburg, Sweden
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Gothenburg%2C+Sweden
# Retrieved 2676 characters {    "results" : [
#
# Resolving Polytechnic University of Timisoara
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Polytechnic+University+of+Timisoara
# Retrieved 1748 characters {    "results" : [
#
# Resolving University of Hawaii (Go, Rainbows!)
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Hawaii+%28Go%2C+Rainbows%21%29
# Retrieved 52 characters {    "results" : [],
#
# Resolving Belarusian State University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Belarusian+State+University
# Retrieved 2067 characters {    "results" : [
#
# Resolving Haaga-Helia university of applied sciences
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Haaga-Helia+university+of+applied+sciences
# Retrieved 52 characters {    "results" : [],
#
# Resolving JADAVPUR UNIVERSITY
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=JADAVPUR+UNIVERSITY
# Retrieved 9950 characters {    "results" : [
#
# Resolving Gauhati University, India
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Gauhati+University%2C+India
# Retrieved 2170 characters {    "results" : [
#
# Resolving Universidad de Buenos Aires
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Universidad+de+Buenos+Aires
# Retrieved 11682 characters {    "results" : [
#
# Resolving Università degli Studi di Genova, Genova, Italia
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Universit%C3%A0+degli+Studi+di+Genova%2C+Genova%2C+Italia
# Retrieved 13548 characters {    "results" : [
#
# Resolving King Mongkut's University of Technology Thonburi
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=King+Mongkut%27s+University+of+Technology+Thonburi
# Retrieved 1952 characters {    "results" : [
#
# Resolving Universidad de la Sabana, Chia, Colombia
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Universidad+de+la+Sabana%2C+Chia%2C+Colombia
# Retrieved 1943 characters {    "results" : [
#
# Resolving State University of New York (SUNY) College at Oswego
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=State+University+of+New+York+%28SUNY%29+College+at+Oswego
# Retrieved 3716 characters {    "results" : [
#
# Resolving Kyrgyz Slavic Russian University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Kyrgyz+Slavic+Russian+University
# Retrieved 52 characters {    "results" : [],
#
# Resolving De La Salle University http://www.dlsu.edu.ph
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=De+La+Salle+University+http%3A%2F%2Fwww.dlsu.edu.ph
# Retrieved 52 characters {    "results" : [],
#
# Resolving Jawaharlal Nehru Technological University, INDIA
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Jawaharlal+Nehru+Technological+University%2C+INDIA
# Retrieved 4872 characters {    "results" : [
#
# Resolving UCL (Université Catholique de Louvain) in Belgium
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=UCL+%28Universit%C3%A9+Catholique+de+Louvain%29+in+Belgium
# Retrieved 1212 characters {    "results" : [
#
# Resolving Boston University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Boston+University
# Retrieved 11888 characters {    "results" : [
#
# Resolving The University of Manchester
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=The+University+of+Manchester
# Retrieved 2127 characters {    "results" : [
#
# Resolving Fachhochschule Düsseldorf
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Fachhochschule+D%C3%BCsseldorf
# Retrieved 2551 characters {    "results" : [
#
# Resolving Pine Manor College (AA), Harvard University (BA), Lesley University (MEd)
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Pine+Manor+College+%28AA%29%2C+Harvard+University+%28BA%29%2C+Lesley+University+%28MEd%29
# Retrieved 52 characters {    "results" : [],
#
# Resolving Simón Bolívar University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Sim%C3%B3n+Bol%C3%ADvar+University
# Retrieved 12694 characters {    "results" : [
#
# Resolving Indiana University at Bloomington
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Indiana+University+at+Bloomington
# Retrieved 2715 characters {    "results" : [
#
# Resolving RPI
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=RPI
# Retrieved 2679 characters {    "results" : [
#
# Resolving University of Ottawa, Canada
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Ottawa%2C+Canada
# Retrieved 13001 characters {    "results" : [
#
# Resolving Ural Federal University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Ural+Federal+University
# Retrieved 52 characters {    "results" : [],
#
# Resolving BITS Pilani
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=BITS+Pilani
# Retrieved 2099 characters {    "results" : [
#
# Resolving Transilvania University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Transilvania+University
# Retrieved 8704 characters {    "results" : [
#
# Resolving IIT(BHU), Varanasi, India
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=IIT%28BHU%29%2C+Varanasi%2C+India
# Retrieved 4708 characters {    "results" : [
#
# Resolving EM Lyon
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=EM+Lyon
# Retrieved 1822 characters {    "results" : [
#
# Resolving Universidad Central de Venezuela
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Universidad+Central+de+Venezuela
# Retrieved 10403 characters {    "results" : [
#
# Resolving NTUU "KPI"
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=NTUU+%22KPI%22
# Retrieved 2523 characters {    "results" : [
#
# Resolving Universidade Federal da Paraiba, Brazil
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Universidade+Federal+da+Paraiba%2C+Brazil
# Retrieved 2344 characters {    "results" : [
#
# Resolving Budapest University of Technology and Economics
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Budapest+University+of+Technology+and+Economics
# Retrieved 1741 characters {    "results" : [
#
# Resolving Moscow Institute of Physics & Technology (State University)
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Moscow+Institute+of+Physics+%26+Technology+%28State+University%29
# Retrieved 3482 characters {    "results" : [
#
# Resolving Saint Petersburg State University of Aerospace Instrumentation, Russia
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Saint+Petersburg+State+University+of+Aerospace+Instrumentation%2C+Russia
# Retrieved 3549 characters {    "results" : [
#
# Resolving North Central College, Naperville, IL
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=North+Central+College%2C+Naperville%2C+IL
# Retrieved 1789 characters {    "results" : [
#
# Resolving Tech. Uni. Denmark (DTU)
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Tech.+Uni.+Denmark+%28DTU%29
# Retrieved 52 characters {    "results" : [],
#
# Resolving Stanford
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Stanford
# Retrieved 1769 characters {    "results" : [
#
# Resolving "Politehnica" Timisoara
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=%22Politehnica%22+Timisoara
# Retrieved 9656 characters {    "results" : [
#
# Resolving National University of Engineering
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=National+University+of+Engineering
# Retrieved 2162 characters {    "results" : [
#
# Resolving Monash
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Monash
# Retrieved 6634 characters {    "results" : [
#
# Resolving Federal University of Campina Grande (UFCG)
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Federal+University+of+Campina+Grande+%28UFCG%29
# Retrieved 2552 characters {    "results" : [
#
# Resolving Universidade Federal do Rio Grande do Sul (UFRGS)
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Universidade+Federal+do+Rio+Grande+do+Sul+%28UFRGS%29
# Retrieved 52 characters {    "results" : [],
#
# Resolving Universidad Nacional Autónoma de México
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Universidad+Nacional+Aut%C3%B3noma+de+M%C3%A9xico
# Retrieved 2059 characters {    "results" : [
#
# Resolving University of New South Wales Harvard Business School
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+New+South+Wales+Harvard+Business+School
# Retrieved 52 characters {    "results" : [],
#
# Resolving University of Tehran
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Tehran
# Retrieved 4270 characters {    "results" : [
#
# Resolving Old Dominion University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Old+Dominion+University
# Retrieved 2413 characters {    "results" : [
#
# Resolving Kyiv Unisersity of Oriental Language
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Kyiv+Unisersity+of+Oriental+Language
# Retrieved 1887 characters {    "results" : [
#
# Resolving Babcock University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Babcock+University
# Retrieved 15641 characters {    "results" : [
#
# Resolving University of Essex
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Essex
# Retrieved 13173 characters {    "results" : [
#
# Resolving Kharkiv National University of Radio Electronics (Ukraine)
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Kharkiv+National+University+of+Radio+Electronics+%28Ukraine%29
# Retrieved 1798 characters {    "results" : [
#
# Resolving Kaunas Technology University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Kaunas+Technology+University
# Retrieved 1775 characters {    "results" : [
#
# Resolving University of Buenos Aires
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Buenos+Aires
# Retrieved 11138 characters {    "results" : [
#
# Resolving University of Jaffna.
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Jaffna.
# Retrieved 8056 characters {    "results" : [
#
# Resolving R V College of Engineering, Bangalore, India for BE in Instrumentation Technology
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=R+V+College+of+Engineering%2C+Bangalore%2C+India+for+BE+in+Instrumentation+Technology
# Retrieved 52 characters {    "results" : [],
#
# Resolving Beloit College
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Beloit+College
# Retrieved 12410 characters {    "results" : [
#
# Resolving UCLA
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=UCLA
# Retrieved 6392 characters {    "results" : [
#
# Resolving University of Chicago
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Chicago
# Retrieved 12534 characters {    "results" : [
#
# Resolving University of Sciences and Technology of Oran. Mohamed Boudiaf (USTO-MB).
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Sciences+and+Technology+of+Oran.+Mohamed+Boudiaf+%28USTO-MB%29.
# Retrieved 52 characters {    "results" : [],
#
# Resolving Zagazig University, Egypt
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Zagazig+University%2C+Egypt
# Retrieved 6945 characters {    "results" : [
#
# Resolving University of Alberta
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Alberta
# Retrieved 12637 characters {    "results" : [
#
# Resolving Belorussian State University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Belorussian+State+University
# Retrieved 2067 characters {    "results" : [
#
# Resolving Jones International University (online) Illinois State Univeristy
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Jones+International+University+%28online%29+Illinois+State+Univeristy
# Retrieved 52 characters {    "results" : [],
#
# Resolving University of Florida
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Florida
# Retrieved 10739 characters {    "results" : [
#
# Resolving Too many to mention.
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Too+many+to+mention.
# Retrieved 52 characters {    "results" : [],
#
# Resolving University of Kerala, India
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Kerala%2C+India
# Retrieved 18085 characters {    "results" : [
#
# Resolving Politecnico di Milano
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Politecnico+di+Milano
# Retrieved 2148 characters {    "results" : [
#
# Resolving Vilnius Gediminas Technical University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Vilnius+Gediminas+Technical+University
# Retrieved 1794 characters {    "results" : [
#
# Resolving Madras university/ Bharthidasan University in India .
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Madras+university%2F+Bharthidasan+University+in+India+.
# Retrieved 1210 characters {    "results" : [
#
# Resolving Universidade Tecnica de Lisboa - Instituto Superior Técnico
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Universidade+Tecnica+de+Lisboa+-+Instituto+Superior+T%C3%A9cnico
# Retrieved 52 characters {    "results" : [],
#
# Resolving Does not apply.
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Does+not+apply.
# Retrieved 52 characters {    "results" : [],
#
# Resolving Stellenbosch University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Stellenbosch+University
# Retrieved 2534 characters {    "results" : [
#
# Resolving imt ghazIABAD INDIA
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=imt+ghazIABAD+INDIA
# Retrieved 2688 characters {    "results" : [
#
# Resolving University of Pennsylvania
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=University+of+Pennsylvania
# Retrieved 7729 characters {    "results" : [
#
# Resolving National Institute of Technology, Jalandhar (India)
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=National+Institute+of+Technology%2C+Jalandhar+%28India%29
# Retrieved 1943 characters {    "results" : [
#
# Resolving Universidad ICESI
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Universidad+ICESI
# Retrieved 52 characters {    "results" : [],
#
# Resolving Virginia Tech
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Virginia+Tech
# Retrieved 4203 characters {    "results" : [
#
# Resolving arizona state university
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=arizona+state+university
# Retrieved 2098 characters {    "results" : [
#
# Resolving Universidad del Valle de Guatemala
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Universidad+del+Valle+de+Guatemala
# Retrieved 5447 characters {    "results" : [
#
# Resolving Mykolas Romeris University, Vilnius, Lithuania
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Mykolas+Romeris+University%2C+Vilnius%2C+Lithuania
# Retrieved 1794 characters {    "results" : [
#
# Resolving BSU
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=BSU
# Retrieved 3623 characters {    "results" : [
#
# Resolving Distance Learning Center at the Technical University of Kaiserslautern in Germany
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Distance+Learning+Center+at+the+Technical+University+of+Kaiserslautern+in+Germany
# Retrieved 1201 characters {    "results" : [
#
# Resolving Ain shams university, Cairo, Egypt
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Ain+shams+university%2C+Cairo%2C+Egypt
# Retrieved 4634 characters {    "results" : [
#
# Resolving Universidad Nacional de Colombia
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Universidad+Nacional+de+Colombia
# Retrieved 11793 characters {    "results" : [
#
# Resolving Saint-Petersburg Polytechnic Univesity
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Saint-Petersburg+Polytechnic+Univesity
# Retrieved 3549 characters {    "results" : [
#
# Resolving NAIT (Northern Alberta Institute of Technology)
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=NAIT+%28Northern+Alberta+Institute+of+Technology%29
# Retrieved 52 characters {    "results" : [],
#
# Resolving Wayne State took courses at U of M
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Wayne+State+took+courses+at+U+of+M
# Retrieved 52 characters {    "results" : [],
#
# Resolving Universidad Nacional, Costa Rica
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Universidad+Nacional%2C+Costa+Rica
# Retrieved 1890 characters {    "results" : [
#
# Resolving Marietta College (Ohio) Northwestern University
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Marietta+College+%28Ohio%29+Northwestern+University
# Retrieved 11292 characters {    "results" : [
#
# Resolving Grandville
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Grandville
# Retrieved 1752 characters {    "results" : [
#
# Resolving Portland State University, Oregon Institute of Technology
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Portland+State+University%2C+Oregon+Institute+of+Technology
# Retrieved 52 characters {    "results" : [],
#
# Resolving Malayer Azad University, Iran
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Malayer+Azad+University%2C+Iran
# Retrieved 1561 characters {    "results" : [
#
# Resolving , university of Tehran
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=%2C+university+of+Tehran
# Retrieved 4270 characters {    "results" : [
# Run geodump.py to read the data from the database so you can visualize it on a map.

# %%
# %load geodump.py
import sqlite3
import json
import codecs

conn = sqlite3.connect('geodata.sqlite')
cur = conn.cursor()

cur.execute('SELECT * FROM Locations')
fhand = codecs.open('where.js','w', "utf-8")
fhand.write("myData = [\n")
count = 0
for row in cur :
    data = str(row[1])
    try: js = json.loads(str(data))
    except: continue

    if not('status' in js and js['status'] == 'OK') : continue

    lat = js["results"][0]["geometry"]["location"]["lat"]
    lng = js["results"][0]["geometry"]["location"]["lng"]
    if lat == 0 or lng == 0 : continue
    where = js['results'][0]['formatted_address']
    where = where.replace("'","")
    try :
        print where, lat, lng

        count = count + 1
        if count > 1 : fhand.write(",\n")
        output = "["+str(lat)+","+str(lng)+", '"+where+"']"
        fhand.write(output)
    except:
        continue

fhand.write("\n];\n")
cur.close()
fhand.close()
