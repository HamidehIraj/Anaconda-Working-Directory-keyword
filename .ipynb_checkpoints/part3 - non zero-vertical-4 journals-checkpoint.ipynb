# %% [markdown]
# # Loading Data

# %%
data <- read.csv("D:/Research/keyword/Keyword/All/4 journals.csv")
nrow(data)
# str(data)
# Out:
# [1] 2887

# %% [markdown]
# # Transforming Variables

# %%
zero_index <- which (data$cited.by == 0 )
print(length(zero_index))

data <- data[-zero_index, ]
dim(data)[1]
# Out:
# [1] 425
# [1] 2462

# %%
# cited.by.table <- table(data$cited.by)
# # cited.by.table
# # round(prop.table(cited.by.table),2) # row percentages 
# rbind(cited.by.table,round(prop.table(cited.by.table),2))

# ##------------------------------------
# cited.by.table <- table(log(data$cited.by_zero))
# # cited.by.table
# # round(prop.table(cited.by.table),2) # row percentages 
# rbind(cited.by.table,round(prop.table(cited.by.table),2))

# %% [markdown]
# # Data Cleaning

# %%
nrow(data)
summary(data$cited.by_scaled)

data <- data[data$cited.by_scaled <4,]
nrow(data)
summary(data$cited.by_scaled)
# Out:
# [1] 2462
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# -0.6446 -0.4722 -0.2259  0.1138  0.2494 11.7000
# [1] 2425
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
# -0.64460 -0.48420 -0.25050  0.02894  0.21750  3.96100

# %% [markdown]
# # Creating New Target Variables

# %%
# hist   (log(data$cited.by))
#barplot(log(data$cited.by))

# %% [markdown]
# # Part 3: Linear Regression in citation >0

# %%
pred_numeric <- c("abstract_length" ,"page.count","title_length", "abstract_ratio" ,"no_references","no_authors"
                  ,"numkeys", "cited.by", "article_age","weight_ratio")
pred_cat     <- c("source.title")
pred_data     <- data[,c(pred_numeric,pred_cat)]
nrow(data)

linear_reg   <- lm(log(cited.by) ~ ., data=pred_data)
summary(linear_reg)
# Out:
# [1] 2425
# Call:
# lm(formula = log(cited.by) ~ ., data = pred_data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4.0795 -0.6406  0.0546  0.6957  2.8978
#
# Coefficients:
#                                              Estimate Std. Error t value
# (Intercept)                                -0.0244890  0.1484333  -0.165
# abstract_length                             0.0004915  0.0003891   1.263
# page.count                                 -0.0184434  0.0059099  -3.121
# title_length                                0.0006911  0.0050836   0.136
# abstract_ratio                             -0.1153992  0.9628297  -0.120
# no_references                               0.0076094  0.0010836   7.022
# no_authors                                  0.0164513  0.0141111   1.166
# numkeys                                    -0.0132830  0.0172210  -0.771
# article_age                                 0.1835199  0.0081721  22.457
# weight_ratio                               -0.2438600  0.5697938  -0.428
# source.titlecomputers and education         1.3691244  0.0665858  20.562
# source.titlecomputers in education journal -1.4563923  0.2563328  -5.682
# source.titleperspectives in education      -0.3657587  0.1043572  -3.505
#                                            Pr(>|t|)
# (Intercept)                                0.868971
# abstract_length                            0.206620
# page.count                                 0.001825 **
# title_length                               0.891871
# abstract_ratio                             0.904609
# no_references                              2.83e-12 ***
# no_authors                                 0.243793
# numkeys                                    0.440589
# article_age                                 < 2e-16 ***
# weight_ratio                               0.668704
# source.titlecomputers and education         < 2e-16 ***
# source.titlecomputers in education journal 1.49e-08 ***
# source.titleperspectives in education      0.000465 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 1.012 on 2412 degrees of freedom
# Multiple R-squared:  0.4004,	Adjusted R-squared:  0.3974
# F-statistic: 134.2 on 12 and 2412 DF,  p-value: < 2.2e-16

# %% [markdown]
# # Model Selection

# %%
# length(which(data$cited.by_zero >0))

# pred_numeric <- c("abstract_length" ,"page.count","title_length", "abstract_ratio" ,"no_references","no_authors"
#                   ,"numkeys", "cited.by", "article_age")
# pred_cat     <- c("source.title")
# pred_data     <- data[,c(pred_numeric,pred_cat)]


# linear_reg   <- lm(cited.by ~ ., data=pred_data)


# summary(linear_reg)

# %%
# linear_reg_step <- step(linear_reg)
# linear_reg_step

# %%
# linear_reg_final <- lm(log(cited.by_zero) ~ page.count + abstract_ratio + 
#     no_references + article_age + source.title, data = pred_data)
# summary(linear_reg_final)

# %%
require(car,quietly=TRUE)
qqPlot(linear_reg, main="QQ Plot") #qq plot for studentized resid 
# qqPlot(linear_reg0, main="QQ Plot") #qq plot for studentized resid
# Out:
# Plot with title "QQ Plot"

# %% [markdown]
# # Outlier Detection

# %%
# influenceIndexPlot <- influenceIndexPlot(linear_reg, id.n=10)
# str(influenceIndexPlot)
# outlierTest(linear_reg)
# data[c(903,908,925),]

# %%
# # Influence Plot 
# influencePlot(linear_reg,	id.method="identify", main="Influence Plot", 
#               sub="Circle size is proportial to Cook's Distance",id.n=10 )

# %% [markdown]
# # Box-Cox Transformation

# %%
require(MASS, quietly=TRUE)
require(car, quietly=TRUE)

#bcPower(1:5,2)
boxCox <- boxCox(linear_reg, lambda = seq(-0.1, 0.1, by=0.1))
summary(powerTransform(linear_reg))
# Out:
# bcPower Transformation to Normality
#
#    Est.Power Std.Err. Wald Lower Bound Wald Upper Bound
# Y1   -0.0053   0.0139          -0.0325           0.0219
#
# Likelihood ratio tests about transformation parameters
#                                LRT df      pval
# LR test, lambda = (0)    0.1446884  1 0.7036639
# LR test, lambda = (1) 4421.8376434  1 0.0000000
# plot without title

# %% [markdown]
# # Multi-Collinearity

# %%
require(car,quietly=TRUE)
# Evaluate Collinearity

vif(linear_reg) # variance inflation factors 
# ??vif
sqrt(vif(linear_reg)) > 2 # problem?
##---------------------------------------------
# Out:
#                     GVIF Df GVIF^(1/(2*Df))
# abstract_length 1.118701  1        1.057687
# page.count      1.331154  1        1.153756
# title_length    1.076800  1        1.037690
# abstract_ratio  1.583023  1        1.258182
# no_references   1.364371  1        1.168063
# no_authors      1.091119  1        1.044566
# numkeys         1.185332  1        1.088729
# article_age     1.601279  1        1.265417
# weight_ratio    1.358452  1        1.165526
# source.title    1.394501  3        1.056987
#                  GVIF    Df GVIF^(1/(2*Df))
# abstract_length FALSE FALSE           FALSE
# page.count      FALSE FALSE           FALSE
# title_length    FALSE FALSE           FALSE
# abstract_ratio  FALSE FALSE           FALSE
# no_references   FALSE FALSE           FALSE
# no_authors      FALSE FALSE           FALSE
# numkeys         FALSE FALSE           FALSE
# article_age     FALSE FALSE           FALSE
# weight_ratio    FALSE FALSE           FALSE
# source.title    FALSE FALSE           FALSE

# %%
confint(linear_reg)
confint(linear_reg2)
# Out:
#                                            2.5 %       97.5 %
# (Intercept)                         -29.62180646 -10.56558169
# abstract_length                      -0.04850754   0.00531413
# page.count                            0.17111616   0.95590560
# title_length                         -0.49949594   0.19057742
# abstract_ratio                       25.23705315 144.23139006
# no_references                         0.05223696   0.21216736
# no_authors                           -1.16743218   0.73312095
# numkeys                              -0.60867130   1.77403031
# article_age                           2.70568141   3.77304059
# source.titlecomputers and education  13.63812024  24.34024598
#                                            2.5 %        97.5 %
# (Intercept)                         -0.699594432  1.8189091038
# abstract_length                     -0.008204656 -0.0008581487
# page.count                          -0.011296098  0.0870355989
# title_length                        -0.081702954  0.0130371166
# abstract_ratio                       0.622934827 17.0929026607
# no_references                        0.012086150  0.0321882777
# no_authors                          -0.140077705  0.1206526700
# numkeys                             -0.073870098  0.2560488839
# source.titlecomputers and education  2.681360673  4.0785562615

# %%
hist(log(data$cited.by+0.5))
# Out:
# Plot with title "Histogram of log(data$cited.by + 0.5)"

# %%
save.image()
