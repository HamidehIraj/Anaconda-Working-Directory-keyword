# %% [markdown]
# # Loading Data

# %%
require(car,quietly=TRUE)
data <- read.csv("D:/Research 2014-2015/Data Quality/keyword/Keyword/data.csv")

## The database is attached to the R search path. so objects in the database can be accessed by simply giving their names.
## attach(data,warn.conflicts = FALSE)

# %% [markdown]
# # Data Cleaning

# %%
## subsetting papers with document.type=="article"
data <- data[data$document.type=="article",]

dim(data)
# Out:
# [1] 346  61

# %%
## random sampling
set.seed(2)
random_index <- sample(1:nrow(data), size = 50, replace = FALSE, prob = NULL)
print(random_index)
data <- data[random_index,]
#unique(data$review)
#names(data)
# Out:
#  [1]  64 243 198  58 323 322  44 283 159 186 337  81 255  61 135 339 342  75 146
# [20]  25 216 126 272  49 112 157  48 114 307  42   4  52 334 324 161 196 262  89
# [39] 206  47 301  91  35  50 286 240 293 105 150 241

# %% [markdown]
# # Creating Predictors and Target

# %%
## "abstract_sum","title_sum",
##  "article_squaredage" 
## "review"

predictors <- c("no_authors","article_age","page.count","no_references",
                "abstract_length","title_length",
                "abstract_ratio"
               )

## title_length
## no of keywords
names(data)

target <- c("cited.by")

data <- data[,c(predictors,target)]
data <- na.omit(data)

str(data)
# Out:
#  [1] "X"                             "ï..authors"
#  [3] "title"                         "year"
#  [5] "source.title"                  "volume"
#  [7] "issue"                         "art..no."
#  [9] "page.start"                    "page.end"
# [11] "page.count"                    "cited.by"
# [13] "link"                          "affiliations"
# [15] "authors.with.affiliations"     "abstract"
# [17] "author.keywords"               "index.keywords"
# [19] "references"                    "publisher"
# [21] "issn"                          "isbn"
# [23] "coden"                         "language.of.original.document"
# [25] "document.type"                 "source"
# [27] "numkeys"                       "k01"
# [29] "k01_abstract"                  "k01_title"
# [31] "k02"                           "k02_abstract"
# [33] "k02_title"                     "k03"
# [35] "k03_abstract"                  "k03_title"
# [37] "k04"                           "k04_abstract"
# [39] "k04_title"                     "k05"
# [41] "k05_abstract"                  "k05_title"
# [43] "k06"                           "k06_abstract"
# [45] "k06_title"                     "k07"
# [47] "k07_abstract"                  "k07_title"
# [49] "abstract_sum"                  "title_sum"
# [51] "abstract_title_sum"            "no_authors"
# [53] "article_age"                   "article_squaredage"
# [55] "abstract_length"               "title_length"
# [57] "no_pages"                      "no_references"
# [59] "review"                        "title_ratio"
# [61] "abstract_ratio"
# 'data.frame':	50 obs. of  8 variables:
#  $ no_authors     : int  2 4 1 3 4 3 3 1 2 4 ...
#  $ article_age    : int  1 2 1 1 2 2 1 2 1 1 ...
#  $ page.count     : int  16 14 12 24 11 12 9 9 13 12 ...
#  $ no_references  : int  68 49 63 113 36 83 40 48 77 48 ...
#  $ abstract_length: int  189 219 154 127 213 173 167 302 199 198 ...
#  $ title_length   : int  11 12 11 21 13 7 14 12 14 10 ...
#  $ abstract_ratio : num  0 0.0228 0.013 0.0157 0 ...
#  $ cited.by       : int  0 0 2 0 4 2 1 1 2 3 ...

# %% [markdown]
# # Data Cleaning

# %%
data <- data[which(!(row.names(data) %in% c(242,275,257,296,310,337,188,326,63,289,163,49,128,48))),]

# %% [markdown]
# # Linear Regression

# %%
uni_linear_reg<- lm(cited.by ~ abstract_ratio , data=data)
plot(cited.by ~ abstract_ratio , data=data,col ="darkgreen")
abline(uni_linear_reg)
# Out:
# plot without title

# %% [markdown]
# # Heatmap

# %%
#par(cex.lab=25)
windows.options(width=1000, height=2000)
heatmap(as.matrix(data[,c(predictors)]), Colv=F, scale='column',cexCol = 0.75, margins = c(6,6) )
# Out:
# plot without title

# %% [markdown]
# # Correlation Matrix

# %%
## put (absolute) correlations on the upper panels,
## with size proportional to the correlations.
panel.cor <- function(x, y, digits = 2, prefix = "", cex.cor, ...)
{
    usr <- par("usr"); on.exit(par(usr))
    par(usr = c(0, 1, 0, 1))
    # r <- abs(cor(x, y))

    r <- cor(x, y)
    txt <- format(c(r, 0.123456789), digits = digits)[1]
    txt <- paste0(prefix, txt)
    if(missing(cex.cor)) cex.cor <- 0.8/strwidth(txt)
    
    # removing the propotional property    
    # text(0.5, 0.5, txt, cex = cex.cor * r)
    text(0.5, 0.5, txt)
   
}
    
pairs(data[,predictors],lower.panel = panel.smooth, upper.panel = panel.cor)
# Out:
# plot without title

# %% [markdown]
# # Building Preliminary Linear Regression Model

# %%
linear_reg <- lm(cited.by ~ . , data=data)

print('Preliminary Regression model')
summary(linear_reg)
# Out:
# [1] "Preliminary Regression model"
# Call:
# lm(formula = cited.by ~ ., data = data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4.2248 -1.2940 -0.1965  0.8844 11.0942
#
# Coefficients:
#                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)     -1.434e+00  3.394e+00  -0.422 0.674890
# no_authors       6.971e-02  2.069e-01   0.337 0.737912
# article_age      3.350e+00  8.883e-01   3.771 0.000503 ***
# page.count       4.188e-02  1.290e-01   0.325 0.747011
# no_references    9.447e-04  2.553e-02   0.037 0.970655
# abstract_length -1.200e-02  8.502e-03  -1.412 0.165347
# title_length     7.882e-02  9.267e-02   0.851 0.399847
# abstract_ratio  -3.543e+01  1.962e+01  -1.806 0.078081 .
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2.745 on 42 degrees of freedom
# Multiple R-squared:  0.389,	Adjusted R-squared:  0.2871
# F-statistic:  3.82 on 7 and 42 DF,  p-value: 0.002696

# %% [markdown]
# # Preliminary QQ Plot

# %%
qqPlot(linear_reg, main=" Preliminary QQ Plot") #qq plot for studentized resid 
#leveragePlots(linear_reg) # leverage plots
# Out:
# Plot with title " Preliminary QQ Plot"

# %% [markdown]
# # Regression Model 2

# %%
print ('Regression Model 2')
linear_reg <- lm(cited.by ~ . , data=data)
summary(linear_reg)
#which (!(row.names(data) %in% c(249,170)))

#(row.names(data) %in% c(249,170))
dim(data)
# Out:
# [1] "Regression Model 2"
# Call:
# lm(formula = cited.by ~ ., data = data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.92404 -0.37639 -0.04426  0.33371  1.12401
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)      2.526350   0.964785   2.619  0.01409 *
# no_authors      -0.101172   0.071502  -1.415  0.16811
# article_age      0.548674   0.256292   2.141  0.04114 *
# page.count      -0.092814   0.035389  -2.623  0.01395 *
# no_references   -0.004718   0.006320  -0.747  0.46152
# abstract_length -0.007428   0.002169  -3.425  0.00192 **
# title_length     0.047350   0.022515   2.103  0.04457 *
# abstract_ratio  12.886210   5.601052   2.301  0.02907 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.5939 on 28 degrees of freedom
# Multiple R-squared:  0.6741,	Adjusted R-squared:  0.5926
# F-statistic: 8.274 on 7 and 28 DF,  p-value: 1.822e-05
# [1] 36  8

# %% [markdown]
# # Regression Model 3

# %%
## After removing non-significant variables
predictors3 <- c("no_authors","article_age",
                "title_length",
                "abstract_ratio"
               )

## title_length
## no of keywords
names(data)

target3 <- c("cited.by")

data3 <- data[,c(predictors3,target3)]
data3 <- na.omit(data3)

print ('Regression Model 3')
linear_reg <- lm(cited.by ~ . , data=data3)
summary(linear_reg)
# Out:
# [1] "no_authors"      "article_age"     "page.count"      "no_references"
# [5] "abstract_length" "title_length"    "abstract_ratio"  "cited.by"
# [1] "Regression Model 3"
# Call:
# lm(formula = cited.by ~ ., data = data3)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.30936 -0.30539  0.03959  0.23989  1.58569
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)      3.00034    0.80132   3.744 0.000908 ***
# no_authors      -0.33417    0.10727  -3.115 0.004443 **
# article_age      1.37645    0.32427   4.245 0.000246 ***
# title_length    -0.15518    0.02919  -5.316 1.46e-05 ***
# abstract_ratio -17.71286    6.54645  -2.706 0.011871 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.7102 on 26 degrees of freedom
# Multiple R-squared:  0.7397,	Adjusted R-squared:  0.6997
# F-statistic: 18.47 on 4 and 26 DF,  p-value: 2.674e-07

# %% [markdown]
# # QQplot 2

# %%
qqPlot(linear_reg, main="QQ Plot 2") #qq plot for studentized resid
# Out:
# Plot with title "QQ Plot 2"

# %% [markdown]
# # Influence Index Plot

# %%
influenceIndexPlot(linear_reg, id.n=3)
# Out:
# plot without title

# %%
## examining influential points

#data[which ((row.names(data) %in% c(257,35,145,310))),]
#data <- data[which (!(row.names(data) %in% c(257,35,145,310))),]

# %%
# Influence Plot 
influencePlot(linear_reg,	id.method="identify", main="Influence Plot", 
              sub="Circle size is proportial to Cook's Distance",id.n=3 )
# Out:
# Plot with title "Influence Plot"

# %% [markdown]
# # Multi-Collinearity

# %%
# Evaluate Collinearity
vif(linear_reg) # variance inflation factors 
# ??vif
sqrt(vif(linear_reg)) > 2 # problem?
# Out:
#      no_authors     article_age      page.count   no_references abstract_length
#        1.123180        1.249252        1.635275        2.002933        1.237178
#    title_length  abstract_ratio
#        1.077874        1.423312
#      no_authors     article_age      page.count   no_references abstract_length
#           FALSE           FALSE           FALSE           FALSE           FALSE
#    title_length  abstract_ratio
#           FALSE           FALSE

# %% [markdown]
# # Normality of Residuals

# %%
# qq plot for studentized resid
# qqPlot(linear_reg, main="QQ Plot")
# distribution of studentized residuals

library(MASS)
sresid <- studres(linear_reg) 
hist(sresid, freq=FALSE, 
   main="Distribution of Studentized Residuals")
xfit<-seq(min(sresid),max(sresid),length=40) 
yfit<-dnorm(xfit) 
lines(xfit, yfit)
# Out:
# Plot with title "Distribution of Studentized Residuals"

# %%
# Non-constant Error Variance

# Evaluate homoscedasticity
# non-constant error variance test
ncvTest(linear_reg)

# plot studentized residuals vs. fitted values 
spreadLevelPlot(linear_reg)
# Out:
# Non-constant Variance Score Test
# Variance formula: ~ fitted.values
# Chisquare = 0.2198788    Df = 1     p = 0.6391323
# Warning message:
# In spreadLevelPlot.lm(linear_reg): 3 negative fitted values removed
# Suggested power transformation:  0.9249757
# Plot with title "Spread-Level Plot for
#  linear_reg"

# %%
options(warn=-1)

# Evaluate Nonlinearity
# component + residual plot 
crPlots(linear_reg)
# Ceres plots 
ceresPlots(linear_reg)
# Out:
# Error in lm.fit(x, y, offset = offset, singular.ok = singular.ok, ...): 0 (non-NA) cases
# plot without title
# Plot with title ""

# %% [markdown]
# # The Book Code

# %% [markdown]
# # Pearson Residuals

# %%
## Pearson residuals versus each of the predictors and versus the fitted values
## page 288
residualPlots(linear_reg)
# Out:
#                Test stat Pr(>|t|)
# no_authors         0.371    0.714
# article_age       -2.252    0.033
# title_length      -1.272    0.215
# abstract_ratio     0.772    0.448
# Tukey test         0.739    0.460
# plot without title

# %% [markdown]
# # Studentized Residuals

# %%
## Studentized residuals versus each of the predictors and versus the fitted values
## page 288
residualPlots(linear_reg, type="rstudent")
# Out:
#                Test stat Pr(>|t|)
# no_authors         0.371    0.714
# article_age       -2.252    0.033
# title_length      -1.272    0.215
# abstract_ratio     0.772    0.448
# Tukey test         0.739    0.460
# plot without title

# %% [markdown]
# # MARGINAL MODEL PLOTS

# %%
## A variation on the basic residual plot is themarginal model plot, proposed by Cook and Weisberg (1997)
marginalModelPlots(linear_reg)
## SD argument, if set to TRUE adds estimated standard deviation lines to the graph.
# Out:
# plot without title

# %% [markdown]
# # Influence Index Plot

# %%
influenceIndexPlot(linear_reg, id.n=3)
# Out:
# plot without title

# %% [markdown]
# # ADDED-VARIABLE PLOTS AS INFLUENCE DIAGNOSTICS

# %%
avPlots(linear_reg, id.n=3)
# Out:
# Plot with title ""

# %%
save.image()
