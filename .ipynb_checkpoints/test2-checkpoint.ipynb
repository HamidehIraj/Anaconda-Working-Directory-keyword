# %%
# URL <- "http://www.math.uah.edu/stat/data/Galton.csv"
# download.file(URL, destfile = "./galton.csv", method="curl")
data <-read.csv("galton.csv")
head(data)
# Out:
#   Family Father Mother Gender Height Kids
# 1      1   78.5   67.0      M   73.2    4
# 2      1   78.5   67.0      F   69.2    4
# 3      1   78.5   67.0      F   69.0    4
# 4      1   78.5   67.0      F   69.0    4
# 5      2   75.5   66.5      M   73.5    4
# 6      2   75.5   66.5      M   72.5    4

# %%
library(repr)
options(repr.plot.width=3, repr.plot.height=3)

for (colname in names(data[,c(2,3,5,6)]))
{hist(data[,colname],main=colname,xlab="")}
# Out:
# Plot with title "Father"
# Error in title(main = main, sub = sub, xlab = xlab, ylab = ylab, ...): invalid graphics state
# Plot with title "Mother"
